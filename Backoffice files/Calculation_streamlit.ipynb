# %%
import streamlit as st
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv(r'c:\Users\gabri\Documents\Data Analysis\IronHack\Unit 6 - Tableau\D3\supermarket_sales.csv')

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
df['City'].unique()
# Out:
# <ArrowStringArray>
# ['Yangon', 'Naypyitaw', 'Mandalay']
# Length: 3, dtype: str

# %%
['All'] + list(df['City'].unique())
# Out:
# ['All', 'Yangon', 'Naypyitaw', 'Mandalay']

# %%
df['Gender'].unique()
# Out:
# <ArrowStringArray>
# ['Female', 'Male']
# Length: 2, dtype: str

# %%
df['Rating']
# Out:
# 0      9.1
# 1      9.6
# 2      7.4
# 3      8.4
# 4      5.3
#       ...
# 995    6.2
# 996    4.4
# 997    7.7
# 998    4.1
# 999    6.6
# Name: Rating, Length: 1000, dtype: float64

# %%
df['Payment'].unique()
# Out:
# <ArrowStringArray>
# ['Ewallet', 'Cash', 'Credit card']
# Length: 3, dtype: str

# %%
#test on filtering city
filtered_df = df.copy()

#City
filtered_df = filtered_df[filtered_df['City'] == 'Yangon']

filtered_df
# Out:
#       Invoice ID Branch    City Customer type  Gender            Product line  \
# 0    750-67-8428      A  Yangon        Member  Female       Health and beauty
# 2    631-41-3108      A  Yangon        Normal    Male      Home and lifestyle
# 3    123-19-1176      A  Yangon        Member    Male       Health and beauty
# 4    373-73-7910      A  Yangon        Normal    Male       Sports and travel
# 6    355-53-5943      A  Yangon        Member  Female  Electronic accessories
# ..           ...    ...     ...           ...     ...                     ...
# 990  886-18-2897      A  Yangon        Normal  Female      Food and beverages
# 992  745-74-0715      A  Yangon        Normal    Male  Electronic accessories
# 997  727-02-1313      A  Yangon        Member    Male      Food and beverages
# 998  347-56-2442      A  Yangon        Normal    Male      Home and lifestyle
# 999  849-09-3807      A  Yangon        Member  Female     Fashion accessories
#
# ...

# %%
#test on filtering gender
filtered_df = df.copy()

#City
filtered_df = filtered_df[filtered_df['Gender'] == 'Male']

filtered_df
# Out:
#       Invoice ID Branch       City Customer type Gender  \
# 2    631-41-3108      A     Yangon        Normal   Male
# 3    123-19-1176      A     Yangon        Member   Male
# 4    373-73-7910      A     Yangon        Normal   Male
# 5    699-14-3026      C  Naypyitaw        Normal   Male
# 11   529-56-3974      B   Mandalay        Member   Male
# ..           ...    ...        ...           ...    ...
# 992  745-74-0715      A     Yangon        Normal   Male
# 993  690-01-6631      B   Mandalay        Normal   Male
# 995  233-67-5758      C  Naypyitaw        Normal   Male
# 997  727-02-1313      A     Yangon        Member   Male
# 998  347-56-2442      A     Yangon        Normal   Male
#
#                Product line  Unit price  Quantity   Tax 5%     Total  \
# 2        Home and lifestyle       46.33         7  16.2155  340.5255
# 3         Health and beauty       58.22         8  23.2880  489.0480
# 4         Sports and travel       86.31         7  30.2085  634.3785
# ...

# %%
# test on min_rating
filtered_df = df.copy()

filtered_df = filtered_df[filtered_df['Rating'] >= 5]

filtered_df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 993  690-01-6631      B   Mandalay        Normal    Male
# 994  652-49-6720      C  Naypyitaw        Member  Female
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 997  727-02-1313      A     Yangon        Member    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%     Total  \
# 0         Health and beauty       74.69         7  26.1415  548.9715
# 1    Electronic accessories       15.28         5   3.8200   80.2200
# 2        Home and lifestyle       46.33         7  16.2155  340.5255
# ...

# %%
# test on payment method
filtered_df = df.copy()

filtered_df = filtered_df[filtered_df['Payment'].isin(['Credit card', 'Cash'])]

filtered_df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 8    665-32-9167      A     Yangon        Member  Female
# 9    692-92-5582      B   Mandalay        Member  Female
# 11   529-56-3974      B   Mandalay        Member    Male
# ..           ...    ...        ...           ...     ...
# 989  430-53-4718      B   Mandalay        Member    Male
# 990  886-18-2897      A     Yangon        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%     Total  \
# 1    Electronic accessories       15.28         5   3.8200   80.2200
# 2        Home and lifestyle       46.33         7  16.2155  340.5255
# 8         Health and beauty       36.26         2   3.6260   76.1460
# ...

# %%
# test on sales
round(df['Total'].sum(), 2)
# Out:
# np.float64(322966.75)

# %%
# test on ratings
round(df['Rating'].mean(), 2)
# Out:
# np.float64(6.97)

# %%
# test on total transactions
df['Invoice ID'].nunique()
# Out:
# 1000

# %%
# test on avg. price transaction
round(df['Total'].mean(),2)
# Out:
# np.float64(322.97)

# %%
# test on best product line
df['Product line'].value_counts().index[0]
# Out:
# 'Fashion accessories'

# %%
# changing type of the date column
df["Date"] = pd.to_datetime(df["Date"])

# %%
# creating the plot
df.groupby(df['Date'])['Total'].sum()
# Out:
# Date
# 1/1/2019     4745.1810
# 1/10/2019    3560.9490
# 1/11/2019    2114.9625
# 1/12/2019    5184.7635
# 1/13/2019    2451.2040
#                ...
# 3/5/2019     6230.8785
# 3/6/2019     3092.5965
# 3/7/2019     1438.2585
# 3/8/2019     3125.3880
# 3/9/2019     7474.0470
# Name: Total, Length: 89, dtype: float64

# %%
sales_over_time = df.groupby(df['Date'].dt.date)['Total'].sum()
fig, ax = plt.subplots(figsize=(10,5))

ax.plot(sales_over_time)
ax.set_title('Sales over time')
ax.set_xlabel('Date')
ax.set_ylabel('Total Sales')
ax.tick_params(axis='x', rotation=45)

# %%
# get top 5 elements in a column
df.sort_values(by = 'Total', ascending=False).head()
# Out:
#       Invoice ID Branch       City Customer type  Gender         Product line  \
# 350  860-79-0874      C  Naypyitaw        Member  Female  Fashion accessories
# 167  687-47-8271      A     Yangon        Normal    Male  Fashion accessories
# 557  283-26-5248      C  Naypyitaw        Member  Female   Food and beverages
# 699  751-41-9720      C  Naypyitaw        Normal    Male   Home and lifestyle
# 996  303-96-2227      B   Mandalay        Normal  Female   Home and lifestyle
#
#      Unit price  Quantity  Tax 5%    Total       Date   Time      Payment  \
# 350       99.30        10   49.65  1042.65 2019-02-15  14:53  Credit card
# 167       98.98        10   49.49  1039.29 2019-02-08  16:20  Credit card
# 557       98.52        10   49.26  1034.46 2019-01-30  20:23      Ewallet
# 699       97.50        10   48.75  1023.75 2019-01-12  16:18      Ewallet
# 996       97.38        10   48.69  1022.49 2019-03-02  17:16      Ewallet
#
# ...
